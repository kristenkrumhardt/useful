# %% [markdown]
# ## This python notebook extracts a field from the CESM2-LE for regions of interest

# %%
import intake
import matplotlib.pyplot as plt
import xarray as xr
from distributed import Client
from ncar_jobqueue import NCARCluster
import dask
import numpy as np
from dask_jobqueue import PBSCluster
import esmlab

# %% [markdown]
# ### Get some DASK going to speed up processing

# %%
# Setup your PBSCluster
cluster = PBSCluster(
    cores=2, # The number of cores you want
    memory='25 GB', # Amount of memory
    processes=1, # How many processes
    queue='casper', # The type of queue to utilize (/glade/u/apps/dav/opt/usr/bin/execcasper)
    local_directory='$TMPDIR', # Use your local directory
    resource_spec='select=1:ncpus=2:mem=25GB', # Specify resources
    project='NCGD0011', # Input your project ID here
    walltime='04:00:00', # Amount of wall time
    interface='ext', # Interface to use
)
# Scale up
cluster.scale(12)

# Change your url to the dask dashboard so you can see it
dask.config.set({'distributed.dashboard.link':'https://jupyterhub.hpc.ucar.edu/stable/user/{USER}/proxy/{port}/status'})

# Setup your client
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://128.117.208.108:45433' processes=0 threads=0, memory=0 B>

# %%
catalog = intake.open_esm_datastore(
    '/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cesm2-le.json'
)
# Out:
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
catalog.df.experiment.unique()
# Out:
# array(['historical', 'ssp370'], dtype=object)

# %%
#cat.search(component='ocn').df.variable.unique()
catalog.search(component='ocn',variable=['diatChl','spChl','diazChl']).df
# Out:
#      component stream                                    case     member_id  \
# 0          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 1          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 2          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 3          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 4          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# ...        ...    ...                                     ...           ...
# 7795       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 7796       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 7797       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 7798       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 7799       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
#
#      variable start_time end_time     time_range                long_name  \
# 0     diatChl    1850-01  1859-12  185001-185912       Diatom Chlorophyll
# 1     diatChl    1860-01  1869-12  186001-186912       Diatom Chlorophyll
# 2     diatChl    1870-01  1879-12  187001-187912       Diatom Chlorophyll
# 3     diatChl    1880-01  1889-12  188001-188912       Diatom Chlorophyll
# 4     diatChl    1890-01  1899-12  189001-189912       Diatom Chlorophyll
# ...       ...        ...      ...            ...                      ...
# 7795    spChl    2055-01  2064-12  205501-206412  Small Phyto Chlorophyll
# 7796    spChl    2065-01  2074-12  206501-207412  Small Phyto Chlorophyll
# 7797    spChl    2075-01  2084-12  207501-208412  Small Phyto Chlorophyll
# 7798    spChl    2085-01  2094-12  208501-209412  Small Phyto Chlorophyll
# 7799    spChl    2095-01  2100-12  209501-210012  Small Phyto Chlorophyll
#
#        units  vertical_levels frequency  \
# 0     mg/m^3              1.0   month_1
# 1     mg/m^3              1.0   month_1
# 2     mg/m^3              1.0   month_1
# 3     mg/m^3              1.0   month_1
# 4     mg/m^3              1.0   month_1
# ...      ...              ...       ...
# 7795  mg/m^3              1.0   month_1
# 7796  mg/m^3              1.0   month_1
# 7797  mg/m^3              1.0   month_1
# 7798  mg/m^3              1.0   month_1
# 7799  mg/m^3              1.0   month_1
#
#                                                    path  experiment  \
# 0     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 1     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 2     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 3     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 4     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# ...                                                 ...         ...
# 7795  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 7796  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 7797  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 7798  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 7799  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
#
#      forcing_variant  cesm_member_id  control_branch_year  \
# 0              cmip6        1001.001                 1001
# 1              cmip6        1001.001                 1001
# 2              cmip6        1001.001                 1001
# 3              cmip6        1001.001                 1001
# 4              cmip6        1001.001                 1001
# ...              ...             ...                  ...
# 7795            smbb        1301.020                 1301
# 7796            smbb        1301.020                 1301
# 7797            smbb        1301.020                 1301
# 7798            smbb        1301.020                 1301
# 7799            smbb        1301.020                 1301
#
#                 cmip_experiment_id
# 0     CESM2_historical_r1i1001p1f1
# 1     CESM2_historical_r1i1001p1f1
# 2     CESM2_historical_r1i1001p1f1
# 3     CESM2_historical_r1i1001p1f1
# 4     CESM2_historical_r1i1001p1f1
# ...                            ...
# 7795     CESM2_ssp370_r20i1301p1f2
# 7796     CESM2_ssp370_r20i1301p1f2
# 7797     CESM2_ssp370_r20i1301p1f2
# 7798     CESM2_ssp370_r20i1301p1f2
# 7799     CESM2_ssp370_r20i1301p1f2
#
# [7800 rows x 18 columns]

# %%
var = ['diatChl','spChl','diazChl']

# %% [markdown]
# #### future scenario part

# %%
subset = catalog.search(component='ocn',
                        variable=var,
                        experiment='ssp370', #'ssp370',
                        forcing_variant='cmip6',
                       )

# %%
def preprocess(ds):
    #ds=ds.isel(z_t=0)
    ds=ds.isel(z_t_150m=0)
    return ds

# %%
with dask.config.set(**{'array.slicing.split_large_chunks': True}):
    dsets = subset.to_dataset_dict(preprocess=preprocess)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3/3 00:31<00:00]
#     </div>

# %%
add_it_up = 0
for ds in dsets.keys():
    print(ds, len(dsets[ds].member_id))
    add_it_up = add_it_up + len(dsets[ds].member_id)
    
print('total members = ', add_it_up)
# Out:
# ocn.ssp370.pop.h.cmip6.diatChl 50
# ocn.ssp370.pop.h.cmip6.spChl 50
# ocn.ssp370.pop.h.cmip6.diazChl 50
# total members =  150

# %%
my_key = 'ocn.ssp370.pop.h.cmip6.' + var[0]
ds_tmp = dsets[my_key]
#fix time dimension so it's a mean of the timebounds
ds_tmp['time']= ds_tmp.time_bound.compute().mean(dim="d2")

# %%
my_key = 'ocn.ssp370.pop.h.cmip6.' + var[1]
ds_tmp2 = dsets[my_key]
#fix time dimension so it's a mean of the timebounds
ds_tmp2['time']= ds_tmp2.time_bound.compute().mean(dim="d2")

# %%
my_key = 'ocn.ssp370.pop.h.cmip6.' + var[2]
ds_tmp3 = dsets[my_key]
#fix time dimension so it's a mean of the timebounds
ds_tmp3['time']= ds_tmp3.time_bound.compute().mean(dim="d2")

# %%
ds_ssp = xr.merge([ds_tmp, ds_tmp2, ds_tmp3])

# %%
keep_vars=['z_t','z_t_150m','time_bound','dz','TLAT','TLONG','time'] + var

ds_ssp = ds_ssp.drop([v for v in ds_ssp.variables if v not in keep_vars])

# %%
ds_ssp['Chl'] = ds_ssp.diatChl + ds_ssp.diazChl + ds_ssp.spChl

# %%
ds_ssp = ds_ssp.drop(['diatChl','spChl','diazChl'])

# %%
#ds_ssp = ds_ssp.mean(dim='member_id')

# %% [markdown]
# ### get coordinate data for the CESM ocean grid

# %%
import pop_tools
import utils

ds_grid = pop_tools.get_grid('POP_gx1v7')

lons = ds_grid.TLONG
lats = ds_grid.TLAT
area = ds_grid.TAREA
lons_norm = utils.normal_lons(lons)

# %%
ds1 = ds_ssp.isel(time=slice(0,60)).mean(dim=('time','member_id'))

# %%
ds2 = ds_ssp.isel(time=slice(972,1032)).mean(dim=('time','member_id'))

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:   (nlat: 384, nlon: 320, z_t: 60)
# Coordinates:
#   * z_t       (z_t) float32 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
#     z_t_150m  float32 500.0
#     TLONG     (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     TLAT      (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     dz        (z_t) float32 dask.array<chunksize=(60,), meta=np.ndarray>
#     Chl       (nlat, nlon) float32 dask.array<chunksize=(384, 320), meta=np.ndarray>

# %%
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
ds2.Chl.plot(vmin=0,vmax=0.5)

# %%
ds1.Chl.plot(vmin=0,vmax=0.2)

# %%
fig = plt.figure(figsize=(8,15))

################################################################################ 
ax = fig.add_subplot(3,1,1,projection=ccrs.PlateCarree())
ax.set_title('a) Chl, mean 2006-2011', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds1.Chl))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=0, vmax=0.2,transform=ccrs.PlateCarree())
ax.coastlines('10m',linewidth=2)
fig.colorbar(pc,  extend='both', label='Chlorophyll (mg Chl/m3)');


################################################################################ 
ax = fig.add_subplot(3,1,2,projection=ccrs.PlateCarree())
ax.set_title('b) Chl, mean 2096-2100', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.Chl))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=0, vmax=0.2,transform=ccrs.PlateCarree())
ax.coastlines('10m',linewidth=2)
fig.colorbar(pc,  extend='both', label='Chlorophyll (mg Chl/m3)');


################################################################################ 
ax = fig.add_subplot(3,1,3,projection=ccrs.PlateCarree())
ax.set_title('c) ${\Delta}$ Omega aragonite', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.Chl - ds1.Chl))
pc = ax.pcolormesh(lon, lat, field, cmap='PuOr',vmin=-0.1, vmax=0.1,transform=ccrs.PlateCarree())
ax.coastlines('10m',linewidth=2)
fig.colorbar(pc,  extend='both', label='${\Delta}$ Chlorophyll (mg Chl/m3)');
# Out:
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1703: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   shading=shading)
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1703: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   shading=shading)

# %%
fig = plt.figure(figsize=(8,15))

################################################################################ 
ax = fig.add_subplot(3,1,1,projection=ccrs.PlateCarree())
ax.set_title('a) Chl, mean 2006-2011', loc='left')
ax.set_extent([-95, -85, 26, 33], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds1.Chl))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=0, vmax=0.3,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)
fig.colorbar(pc,  extend='both', label='${\Delta}$ Chlorophyll (mg Chl/m3)');

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')
################################################################################ 
ax = fig.add_subplot(3,1,2,projection=ccrs.PlateCarree())
ax.set_title('b) Chl, mean 2096-2100', loc='left')
ax.set_extent([-95, -85, 26, 33], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.Chl))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=0, vmax=0.3,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)
fig.colorbar(pc,  extend='both', label='Chlorophyll (mg Chl/m3)');

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')
################################################################################ 
ax = fig.add_subplot(3,1,3,projection=ccrs.PlateCarree())
ax.set_title('c) ${\Delta}$ Chl', loc='left')
ax.set_extent([-95, -85, 26, 33], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.Chl - ds1.Chl))
pc = ax.pcolormesh(lon, lat, field, cmap='RdYlGn',vmin=-0.2, vmax=0.2,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')



fig.colorbar(pc,  extend='both', label='${\Delta}$ Chlorophyll (mg Chl/m3)');
# Out:
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1703: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   shading=shading)

# %% [markdown]
# #### Make ds2 30 years into the future (mean 2035 to 249), rather than at the end of the century

# %%
ds2 = ds_ssp.isel(time=slice(360,420)).mean(dim=('time','member_id'))

# %% [markdown]
# ### Make a timeseries of changes around Mississippi Sound and Mobile Bay

# %%
box1_latmin = 30
box1_latmax = 31
box1_lonmin = -89
box1_lonmax = -87

# %%
fig = plt.figure(figsize=(8,4))

################################################################################ 
ax = fig.add_subplot(1,1,1,projection=ccrs.PlateCarree())
ax.set_title('${\Delta}$ Chlorophyll, change from present day to 30 years in the future', loc='left')
ax.set_extent([-95, -85, 26, 33], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.Chl - ds1.Chl))
pc = ax.pcolormesh(lon, lat, field, cmap='PuOr_r',
                   vmin=-0.2, vmax=0.2,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')

lon_pts = [box1_lonmin,box1_lonmax,box1_lonmax,box1_lonmin,box1_lonmin]
lat_pts = [box1_latmax,box1_latmax,box1_latmin,box1_latmin,box1_latmax]
ax.plot(lon_pts, lat_pts, color="black", linewidth=1.5,transform=ccrs.PlateCarree())

fig.colorbar(pc,  extend='both', label='${\Delta}$ Chlorophyll (mg/m3)');
# Out:
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1703: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   shading=shading)

# %% [markdown]
# ### Now make timeseries in that box

# %%
ones = np.full((384,320),1,dtype=int)
ones = xr.DataArray(ones,dims=('nlat','nlon'))
ones = ones.where(ds_grid.REGION_MASK>0)

# %%
mask = ones.where(lats<box1_latmax).where(lats>box1_latmin).where(lons_norm<box1_lonmax).where(lons_norm>box1_lonmin)
mask = mask.where(ds_grid.REGION_MASK > 0)

# %%
ds_ssp = ds_ssp.drop(['z_t'])

# %%
def subset_box(da):
    
    masked_var = da.where(mask == 1)
    masked_area = area.where(mask == 1)
    
    da = (masked_var * masked_area).sum(dim=('nlon','nlat')) / (masked_area.sum(dim=('nlon','nlat')))

    da = da.compute()
    
    return da

# %%
# %%time

da_var = subset_box(ds_ssp.Chl)
# Out:
# CPU times: user 16.6 s, sys: 945 ms, total: 17.5 s
# Wall time: 3min 56s

# %%
da_ann = da_var.resample({'time':'A'}).mean(dim='time').compute()

# %%
da_ann['time'] = np.arange(2015,2101,1)

# %%
# %%time

fig = plt.figure(figsize=(12,10))

ax = fig.add_subplot(1,1,1)
ax.set_title('SSP370 Chlorophyll at Mississippi Sound/Mobile Bay region')

da_ensmean = da_ann.mean(dim='member_id')

for mem in np.arange(0,50,1):
    #print(mem)
    ax.plot(da_ann.time, da_ann.isel(member_id=mem),linewidth=1)
    
ax.plot(da_ann.time, da_ensmean,linewidth=2, color='black')

ax.axvline(2017.5,color='lightgray',linewidth=35,zorder=0)
ax.axvline(2047.5,color='lightgray',linewidth=35,zorder=0)
ax.set(ylabel='Chlorophyll (mg m$^{-3}$', xlabel='Year');
# Out:
# CPU times: user 125 ms, sys: 4.31 ms, total: 129 ms
# Wall time: 148 ms
# [Text(0, 0.5, 'Chlorophyll (mg m$^{-3}$'), Text(0.5, 0, 'Year')]

# %%
#cluster.close()
