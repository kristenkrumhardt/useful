# %% [markdown]
# ## This python notebook extracts a field from the CESM2-LE for regions of interest

# %%
import intake
import matplotlib.pyplot as plt
import xarray as xr
from distributed import Client
from ncar_jobqueue import NCARCluster
import dask
import numpy as np
from dask_jobqueue import PBSCluster

# %% [markdown]
# ### Get some DASK going to speed up processing

# %%
# Setup your PBSCluster
cluster = PBSCluster(
    cores=2, # The number of cores you want
    memory='25 GB', # Amount of memory
    processes=1, # How many processes
    queue='casper', # The type of queue to utilize (/glade/u/apps/dav/opt/usr/bin/execcasper)
    local_directory='$TMPDIR', # Use your local directory
    resource_spec='select=1:ncpus=2:mem=25GB', # Specify resources
    project='NCGD0011', # Input your project ID here
    walltime='04:00:00', # Amount of wall time
    interface='ext', # Interface to use
)
# Scale up
cluster.scale(12)

# Change your url to the dask dashboard so you can see it
dask.config.set({'distributed.dashboard.link':'https://jupyterhub.hpc.ucar.edu/stable/user/{USER}/proxy/{port}/status'})

# Setup your client
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://128.117.208.108:44915' processes=0 threads=0, memory=0 B>

# %%
catalog = intake.open_esm_datastore(
    '/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cesm2-le.json'
)
# Out:
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
catalog.df.experiment.unique()
# Out:
# array(['historical', 'ssp370'], dtype=object)

# %%
#cat.search(component='ocn').df.variable.unique()
catalog.search(component='ocn',variable=['co3_sat_arag','CO3']).df
# Out:
#      component stream                                    case     member_id  \
# 0          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 1          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 2          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 3          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 4          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# ...        ...    ...                                     ...           ...
# 5195       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 5196       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 5197       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 5198       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 5199       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
#
#           variable start_time end_time     time_range  \
# 0              CO3    1850-01  1859-12  185001-185912
# 1              CO3    1860-01  1869-12  186001-186912
# 2              CO3    1870-01  1879-12  187001-187912
# 3              CO3    1880-01  1889-12  188001-188912
# 4              CO3    1890-01  1899-12  189001-189912
# ...            ...        ...      ...            ...
# 5195  co3_sat_arag    2055-01  2064-12  205501-206412
# 5196  co3_sat_arag    2065-01  2074-12  206501-207412
# 5197  co3_sat_arag    2075-01  2084-12  207501-208412
# 5198  co3_sat_arag    2085-01  2094-12  208501-209412
# 5199  co3_sat_arag    2095-01  2100-12  209501-210012
#
#                                       long_name     units  vertical_levels  \
# 0                   Carbonate Ion Concentration  mmol/m^3              1.0
# 1                   Carbonate Ion Concentration  mmol/m^3              1.0
# 2                   Carbonate Ion Concentration  mmol/m^3              1.0
# 3                   Carbonate Ion Concentration  mmol/m^3              1.0
# 4                   Carbonate Ion Concentration  mmol/m^3              1.0
# ...                                         ...       ...              ...
# 5195  CO3 concentration at aragonite saturation  mmol/m^3              1.0
# 5196  CO3 concentration at aragonite saturation  mmol/m^3              1.0
# 5197  CO3 concentration at aragonite saturation  mmol/m^3              1.0
# 5198  CO3 concentration at aragonite saturation  mmol/m^3              1.0
# 5199  CO3 concentration at aragonite saturation  mmol/m^3              1.0
#
#      frequency                                               path  experiment  \
# 0      month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 1      month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 2      month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 3      month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 4      month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# ...        ...                                                ...         ...
# 5195   month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 5196   month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 5197   month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 5198   month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 5199   month_1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
#
#      forcing_variant  cesm_member_id  control_branch_year  \
# 0              cmip6        1001.001                 1001
# 1              cmip6        1001.001                 1001
# 2              cmip6        1001.001                 1001
# 3              cmip6        1001.001                 1001
# 4              cmip6        1001.001                 1001
# ...              ...             ...                  ...
# 5195            smbb        1301.020                 1301
# 5196            smbb        1301.020                 1301
# 5197            smbb        1301.020                 1301
# 5198            smbb        1301.020                 1301
# 5199            smbb        1301.020                 1301
#
#                 cmip_experiment_id
# 0     CESM2_historical_r1i1001p1f1
# 1     CESM2_historical_r1i1001p1f1
# 2     CESM2_historical_r1i1001p1f1
# 3     CESM2_historical_r1i1001p1f1
# 4     CESM2_historical_r1i1001p1f1
# ...                            ...
# 5195     CESM2_ssp370_r20i1301p1f2
# 5196     CESM2_ssp370_r20i1301p1f2
# 5197     CESM2_ssp370_r20i1301p1f2
# 5198     CESM2_ssp370_r20i1301p1f2
# 5199     CESM2_ssp370_r20i1301p1f2
#
# [5200 rows x 18 columns]

# %%
var = ['co3_sat_arag','CO3']

# %% [markdown]
# #### future scenario part

# %%
subset = catalog.search(component='ocn',
                        variable=var,
                        experiment='ssp370', #'ssp370',
                        forcing_variant='cmip6',
                       )

# %%
def preprocess(ds):
    ds=ds.isel(z_t=0)
    #ds=ds.isel(z_t_150m=0)
    return ds

# %%
with dask.config.set(**{'array.slicing.split_large_chunks': True}):
    dsets = subset.to_dataset_dict(preprocess=preprocess)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:15<00:00]
#     </div>

# %%
add_it_up = 0
for ds in dsets.keys():
    print(ds, len(dsets[ds].member_id))
    add_it_up = add_it_up + len(dsets[ds].member_id)
    
print('total members = ', add_it_up)
# Out:
# ocn.ssp370.pop.h.cmip6.co3_sat_arag 50
# ocn.ssp370.pop.h.cmip6.CO3 50
# total members =  100

# %%
my_key = 'ocn.ssp370.pop.h.cmip6.' + var[0]
ds_tmp = dsets[my_key]
#fix time dimension so it's a mean of the timebounds
ds_tmp['time']= ds_tmp.time_bound.compute().mean(dim="d2")

# %%
my_key = 'ocn.ssp370.pop.h.cmip6.' + var[1]
ds_tmp2 = dsets[my_key]
#fix time dimension so it's a mean of the timebounds
ds_tmp2['time']= ds_tmp2.time_bound.compute().mean(dim="d2")

# %%
ds_ssp = xr.merge([ds_tmp, ds_tmp2])

# %%
keep_vars=['z_t','z_t_150m','time_bound','dz','TLAT','TLONG','time'] + var

ds_ssp = ds_ssp.drop([v for v in ds_ssp.variables if v not in keep_vars])

# %%
#ds_ssp = ds_ssp.mean(dim='member_id')

# %%
ds_ssp['omega_arag'] = ds_ssp.CO3/ds_ssp.co3_sat_arag

# %% [markdown]
# ### get coordinate data for the CESM ocean grid

# %%
import pop_tools
import utils

ds_grid = pop_tools.get_grid('POP_gx1v7')

lons = ds_grid.TLONG
lats = ds_grid.TLAT
area = ds_grid.TAREA
lons_norm = utils.normal_lons(lons)

# %%
ds1 = ds_ssp.isel(time=slice(0,60)).mean(dim=('time','member_id'))

# %%
ds2 = ds_ssp.isel(time=slice(972,1032)).mean(dim=('time','member_id'))

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:       (nlat: 384, nlon: 320, z_t_150m: 15)
# Coordinates:
#     z_t           float32 500.0
#   * z_t_150m      (z_t_150m) float32 500.0 1.5e+03 2.5e+03 ... 1.35e+04 1.45e+04
#     TLONG         (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     TLAT          (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     dz            float32 dask.array<chunksize=(), meta=np.ndarray>
#     co3_sat_arag  (nlat, nlon) float32 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     CO3           (nlat, nlon) float32 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     omega_arag    (nlat, nlon) float32 dask.array<chunksize=(384, 320), meta=np.ndarray>

# %%
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
ds1['omega_arag'] = ds1.CO3/ds1.co3_sat_arag

# %%
ds2['omega_arag'] = ds2.CO3/ds2.co3_sat_arag

# %%
ds2.omega_arag.plot()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fig = plt.figure(figsize=(8,15))

################################################################################ 
ax = fig.add_subplot(3,1,1,projection=ccrs.PlateCarree())
ax.set_title('a) Omega aragonite, mean 2006-2011', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds1.omega_arag))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=2, vmax=4.5,transform=ccrs.PlateCarree())
ax.coastlines('10m',linewidth=2)
fig.colorbar(pc,  extend='both', label='${\Delta}$ Omega aragonite');


################################################################################ 
ax = fig.add_subplot(3,1,2,projection=ccrs.PlateCarree())
ax.set_title('b) Omega aragonite, mean 2096-2100', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.omega_arag))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=2, vmax=4.5,transform=ccrs.PlateCarree())
ax.coastlines('10m',linewidth=2)
fig.colorbar(pc,  extend='both', label='Omega aragonite');


################################################################################ 
ax = fig.add_subplot(3,1,3,projection=ccrs.PlateCarree())
ax.set_title('c) ${\Delta}$ Omega aragonite', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.omega_arag - ds1.omega_arag))
pc = ax.pcolormesh(lon, lat, field, cmap='PuOr',vmin=-2, vmax=2,transform=ccrs.PlateCarree())
ax.coastlines('10m',linewidth=2)
fig.colorbar(pc,  extend='both', label='${\Delta}$ Omega aragonite');

# %%
fig = plt.figure(figsize=(8,15))

################################################################################ 
ax = fig.add_subplot(3,1,1,projection=ccrs.PlateCarree())
ax.set_title('a) Omega aragonite, mean 2006-2011', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds1.omega_arag))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=2, vmax=4.5,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)
fig.colorbar(pc,  extend='both', label='${\Delta}$ Omega aragonite');

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')
################################################################################ 
ax = fig.add_subplot(3,1,2,projection=ccrs.PlateCarree())
ax.set_title('b) Omega aragonite, mean 2096-2100', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.omega_arag))
pc = ax.pcolormesh(lon, lat, field, cmap='jet',vmin=2, vmax=4.5,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)
fig.colorbar(pc,  extend='both', label='Omega aragonite');

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')
################################################################################ 
ax = fig.add_subplot(3,1,3,projection=ccrs.PlateCarree())
ax.set_title('c) ${\Delta}$ Omega aragonite', loc='left')
ax.set_extent([-100, -75, 20, 37], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.omega_arag - ds1.omega_arag))
pc = ax.pcolormesh(lon, lat, field, cmap='RdYlGn',vmin=-1.3, vmax=-1,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')



fig.colorbar(pc,  extend='both', label='${\Delta}$ Omega aragonite');

# %% [markdown]
# #### Make ds2 30 years into the future (mean 2035 to 249), rather than at the end of the century

# %%
ds2 = ds_ssp.isel(time=slice(360,420)).mean(dim=('time','member_id'))
ds2['omega_arag'] = ds2.CO3/ds2.co3_sat_arag

# %% [markdown]
# ### Make a timeseries of changes around Mississippi Sound and Mobile Bay

# %%
box1_latmin = 30
box1_latmax = 31
box1_lonmin = -89
box1_lonmax = -87

# %%
fig = plt.figure(figsize=(8,15))


################################################################################ 
ax = fig.add_subplot(3,1,3,projection=ccrs.PlateCarree())
ax.set_title('${\Delta}$ Omega aragonite, change from present day to 30 years in the future', loc='left')
ax.set_extent([-95, -85, 26, 33], ccrs.PlateCarree())

lon, lat, field = utils.adjust_pop_grid(lons,lats,(ds2.omega_arag - ds1.omega_arag))
pc = ax.pcolormesh(lon, lat, field, cmap='RdYlGn',vmin=-0.5, vmax=0,
                   transform=ccrs.PlateCarree(),zorder=0)
ax.coastlines('10m',linewidth=1,zorder=1)

ax.scatter(-88,30.5,s=40,color='red',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mobile Bay')
ax.scatter(-88.5,30.25,s=40,color='blue',edgecolor='white',
           transform=ccrs.PlateCarree(),zorder=2,label='Mississippi Sound')

lon_pts = [box1_lonmin,box1_lonmax,box1_lonmax,box1_lonmin,box1_lonmin]
lat_pts = [box1_latmax,box1_latmax,box1_latmin,box1_latmin,box1_latmax]
ax.plot(lon_pts, lat_pts, color="black", linewidth=1.5,transform=ccrs.PlateCarree())

fig.colorbar(pc,  extend='both', label='${\Delta}$ Omega aragonite');

# %% [markdown]
# ### Now make timeseries in that box

# %%
ones = np.full((384,320),1,dtype=int)
ones = xr.DataArray(ones,dims=('nlat','nlon'))
ones = ones.where(ds_grid.REGION_MASK>0)

# %%
mask = ones.where(lats<box1_latmax).where(lats>box1_latmin).where(lons_norm<box1_lonmax).where(lons_norm>box1_lonmin)
mask = mask.where(ds_grid.REGION_MASK > 0)

# %%
ds_ssp = ds_ssp.drop(['z_t'])

# %%
def subset_box(da):
    
    masked_var = da.where(mask == 1)
    masked_area = area.where(mask == 1)
    
    da = (masked_var * masked_area).sum(dim=('nlon','nlat')) / (masked_area.sum(dim=('nlon','nlat')))

    da = da.compute()
    
    return da

# %%
# %%time

da_var = subset_box(ds_ssp.omega_arag)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-35-ecd602adcd35> in subset_box(da)
#       6     da = (masked_var * masked_area).sum(dim=('nlon','nlat')) / (masked_area.sum(dim=('nlon','nlat')))
#       7
# ----> 8     da = da.compute()
#       9
#      10     return da
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/xarray/core/dataarray.py in compute(self, **kwargs)
#     897         """
#     898         new = self.copy(deep=False)
# --> 899         return new.load(**kwargs)
#     900
#     901     def persist(self, **kwargs) -> "DataArray":
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     871         dask.compute
#     872         """
# --> 873         ds = self._to_temp_dataset().load(**kwargs)
#     874         new = self._from_temp_dataset(ds)
#     875         self._variable = new._variable
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     796
#     797             # evaluate all the dask arrays simultaneously
# --> 798             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     799
#     800             for k, data in zip(lazy_data, evaluated_data):
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     565         postcomputes.append(x.__dask_postcompute__())
#     566
# --> 567     results = schedule(dsk, keys, **kwargs)
#     568     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     569
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/distributed/client.py in get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2664                     should_rejoin = False
#    2665             try:
# -> 2666                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2667             finally:
#    2668                 for f in futures.values():
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1979                 direct=direct,
#    1980                 local_worker=local_worker,
# -> 1981                 asynchronous=asynchronous,
#    1982             )
#    1983
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     842         else:
#     843             return sync(
# --> 844                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     845             )
#     846
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     348     else:
#     349         while not e.is_set():
# --> 350             e.wait(10)
#     351     if error[0]:
#     352         typ, exc, tb = error[0]
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
da_ann = da_var.resample({'time':'A'}).mean(dim='time').compute()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-8a5aab43e018> in <module>
# ----> 1 da_ann = da_var.resample({'time':'A'}).mean(dim='time').compute()
#
# NameError: name 'da_var' is not defined

# %%
da_ann['time'] = np.arange(2015,2101,1)

# %%
# %%time

fig = plt.figure(figsize=(12,10))

ax = fig.add_subplot(1,1,1)
ax.set_title('SSP370 Omega aragonite at Mississippi Sound/Mobile Bay region')

da_ensmean = da_ann.mean(dim='member_id')

for mem in np.arange(0,50,1):
    #print(mem)
    ax.plot(da_ann.time, da_ann.isel(member_id=mem),linewidth=1)
    
ax.plot(da_ann.time, da_ensmean,linewidth=2, color='black')

ax.axvline(2017.5,color='lightgray',linewidth=35,zorder=0)
ax.axvline(2047.5,color='lightgray',linewidth=35,zorder=0)
ax.set(ylabel='Omega aragonite', xlabel='Year');

# %%
#cluster.close()
