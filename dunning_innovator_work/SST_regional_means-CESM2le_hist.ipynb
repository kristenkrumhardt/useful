# %% [markdown]
# ## This python notebook extracts sea surface temperature data from the CESM2-LE for regions of interest around Florida and the Virgin Islands

# %%
import intake
import matplotlib.pyplot as plt
import xarray as xr
from distributed import Client
from ncar_jobqueue import NCARCluster
import dask
import numpy as np
from dask_jobqueue import PBSCluster
import esmlab

# %% [markdown]
# ### Get some DASK going to speed up processing

# %%
# Setup your PBSCluster
cluster = PBSCluster(
    cores=2, # The number of cores you want
    memory='256 GB', # Amount of memory
    processes=1, # How many processes
    queue='casper', # The type of queue to utilize (/glade/u/apps/dav/opt/usr/bin/execcasper)
    local_directory='$TMPDIR', # Use your local directory
    resource_spec='select=1:ncpus=2:mem=256GB', # Specify resources
    project='NCGD0011', # Input your project ID here
    walltime='03:00:00', # Amount of wall time
    interface='ib0', # Interface to use
)
# Scale up
cluster.scale(8)

# Change your url to the dask dashboard so you can see it
dask.config.set({'distributed.dashboard.link':'https://jupyterhub.hpc.ucar.edu/stable/user/{USER}/proxy/{port}/status'})

# Setup your client
client = Client(cluster)
# Out:
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/distributed/node.py:155: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45337 instead
#   http_address["port"], self.http_server.port

# %%
client
# Out:
# <Client: 'tcp://10.12.206.32:40464' processes=0 threads=0, memory=0 B>

# %%
catalog = intake.open_esm_datastore(
    '/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cesm2-le.json'
)
# Out:
# /glade/work/kristenk/miniconda/envs/analysis5/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
catalog.df.experiment.unique()
# Out:
# array(['historical', 'ssp370'], dtype=object)

# %%
#cat.search(component='ocn').df.variable.unique()
catalog.search(component='ocn',variable='TEMP').df
# Out:
#      component stream                                    case     member_id  \
# 0          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 1          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 2          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 3          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# 4          ocn  pop.h   b.e21.BHISTcmip6.f09_g17.LE2-1001.001   r1i1001p1f1
# ...        ...    ...                                     ...           ...
# 2595       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 2596       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 2597       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 2598       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
# 2599       ocn  pop.h  b.e21.BSSP370smbb.f09_g17.LE2-1301.020  r20i1301p1f2
#
#      variable start_time end_time     time_range              long_name units  \
# 0        TEMP    1850-01  1859-12  185001-185912  Potential Temperature  degC
# 1        TEMP    1860-01  1869-12  186001-186912  Potential Temperature  degC
# 2        TEMP    1870-01  1879-12  187001-187912  Potential Temperature  degC
# 3        TEMP    1880-01  1889-12  188001-188912  Potential Temperature  degC
# 4        TEMP    1890-01  1899-12  189001-189912  Potential Temperature  degC
# ...       ...        ...      ...            ...                    ...   ...
# 2595     TEMP    2055-01  2064-12  205501-206412  Potential Temperature  degC
# 2596     TEMP    2065-01  2074-12  206501-207412  Potential Temperature  degC
# 2597     TEMP    2075-01  2084-12  207501-208412  Potential Temperature  degC
# 2598     TEMP    2085-01  2094-12  208501-209412  Potential Temperature  degC
# 2599     TEMP    2095-01  2100-12  209501-210012  Potential Temperature  degC
#
#       vertical_levels frequency  \
# 0                 1.0   month_1
# 1                 1.0   month_1
# 2                 1.0   month_1
# 3                 1.0   month_1
# 4                 1.0   month_1
# ...               ...       ...
# 2595              1.0   month_1
# 2596              1.0   month_1
# 2597              1.0   month_1
# 2598              1.0   month_1
# 2599              1.0   month_1
#
#                                                    path  experiment  \
# 0     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 1     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 2     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 3     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# 4     /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...  historical
# ...                                                 ...         ...
# 2595  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 2596  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 2597  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 2598  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
# 2599  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/o...      ssp370
#
#      forcing_variant  cesm_member_id  control_branch_year  \
# 0              cmip6        1001.001                 1001
# 1              cmip6        1001.001                 1001
# 2              cmip6        1001.001                 1001
# 3              cmip6        1001.001                 1001
# 4              cmip6        1001.001                 1001
# ...              ...             ...                  ...
# 2595            smbb        1301.020                 1301
# 2596            smbb        1301.020                 1301
# 2597            smbb        1301.020                 1301
# 2598            smbb        1301.020                 1301
# 2599            smbb        1301.020                 1301
#
#                 cmip_experiment_id
# 0     CESM2_historical_r1i1001p1f1
# 1     CESM2_historical_r1i1001p1f1
# 2     CESM2_historical_r1i1001p1f1
# 3     CESM2_historical_r1i1001p1f1
# 4     CESM2_historical_r1i1001p1f1
# ...                            ...
# 2595     CESM2_ssp370_r20i1301p1f2
# 2596     CESM2_ssp370_r20i1301p1f2
# 2597     CESM2_ssp370_r20i1301p1f2
# 2598     CESM2_ssp370_r20i1301p1f2
# 2599     CESM2_ssp370_r20i1301p1f2
#
# [2600 rows x 18 columns]

# %%
#subset = catalog.search(component='ocn',variable='TEMP',experiment='ssp370',forcing_variant='cmip6')
subset = catalog.search(component='ocn',variable='TEMP',experiment='historical',forcing_variant='cmip6')

# %%
with dask.config.set(**{'array.slicing.split_large_chunks': True}):
    dsets = subset.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
dsets.keys()
# Out:
# dict_keys(['ocn.historical.pop.h.cmip6.TEMP'])

# %%
my_key = 'ocn.historical.pop.h.cmip6.TEMP'

# %%
coords = {'x':'TLONG','y':'TLAT'}
keepthese=['TEMP','z_t','z_t_150m','time_bound','TAREA','REGION_MASK']
keep_vars = keepthese +list(coords.values())+['dz','KMT']

ds = dsets[my_key].drop([v for v in dsets[my_key].variables if v not in keep_vars])

# %% [markdown]
# ### Select just the top level (top 10 m) of the ocean temperature data and clip data to 1950 to 2014

# %%
ds = ds.isel(z_t=0)

# %%
#fix time dimension so it's a mean of the timebounds
ds["time"] = ds.time_bound.compute().mean(dim="d2")

# %%
ds["time"].isel(time=slice(1200,1980)) 
## these are the timeslices to get 65 years of monthly data: 1950 to 2014
# Out:
# <xarray.DataArray 'time' (time: 780)>
# array([cftime.DatetimeNoLeap(1950, 1, 16, 12, 0, 0, 0),
#        cftime.DatetimeNoLeap(1950, 2, 15, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(1950, 3, 16, 12, 0, 0, 0), ...,
#        cftime.DatetimeNoLeap(2014, 10, 16, 12, 0, 0, 0),
#        cftime.DatetimeNoLeap(2014, 11, 16, 0, 0, 0, 0),
#        cftime.DatetimeNoLeap(2014, 12, 16, 12, 0, 0, 0)], dtype=object)
# Coordinates:
#     z_t      float32 500.0
#   * time     (time) object 1950-01-16 12:00:00 ... 2014-12-16 12:00:00

# %%
## actually do the time subsetting here
ds = ds.isel(time=slice(1200,1980))

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (d2: 2, member_id: 50, nlat: 384, nlon: 320, time: 780, z_t_150m: 15)
# Coordinates:
#     z_t          float32 500.0
#   * z_t_150m     (z_t_150m) float32 500.0 1.5e+03 2.5e+03 ... 1.35e+04 1.45e+04
#     TLONG        (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     TLAT         (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#   * time         (time) object 1950-01-16 12:00:00 ... 2014-12-16 12:00:00
# Dimensions without coordinates: d2, member_id, nlat, nlon
# Data variables:
#     dz           float32 dask.array<chunksize=(), meta=np.ndarray>
#     KMT          (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     REGION_MASK  (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     TAREA        (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     time_bound   (time, d2) object dask.array<chunksize=(120, 2), meta=np.ndarray>
#     TEMP         (member_id, time, nlat, nlon) float32 dask.array<chunksize=(1, 120, 384, 320), meta=np.ndarray>
# Attributes:
#     intake_esm_varname:      ['TEMP']
#     history:                 none\nnone\nThu Dec  9 19:03:25 2021: ncks -O -F...
#     source:                  CCSM POP2, the CCSM Ocean Component
#     calendar:                All years have exactly  365 days.
#     revision:                $Id$
#     Conventions:             CF-1.0; http://www.cgd.ucar.edu/cms/eaton/netcdf...
#     cell_methods:            cell_methods = time: mean ==> the variable value...
#     contents:                Diagnostic and Prognostic Variables
#     time_period_freq:        month_1
#     NCO:                     netCDF Operators version 4.9.5 (Homepage = http:...
#     model_doi_url:           https://doi.org/10.5065/D67H1H0V
#     intake_esm_dataset_key:  ocn.historical.pop.h.cmip6.TEMP

# %% [markdown]
# ### get coordinate data for the CESM ocean grid

# %%
import pop_tools
import utils

ds_grid = pop_tools.get_grid('POP_gx1v7')

lons = ds_grid.TLONG
lats = ds_grid.TLAT
area = ds_grid.TAREA
lons_norm = utils.normal_lons(lons)

# %% [markdown]
# ### These are areas we're interested in: lon and lat bounds

# %%
## monroe county coastal region (west coast of florida tip)
lonmin_monbox = -83.2
lonmax_monbox = -81.2
latmin_monbox = 25
latmax_monbox = 27

## Miami-dade county coastal region (east coast florida tip)
lonmin_dadebox = -80.8
lonmax_dadebox = -78.8
latmin_dadebox = 25
latmax_dadebox = 27

## US virgin islands region
lonmin_VIbox = -66
lonmax_VIbox = -63
latmin_VIbox = 17
latmax_VIbox = 20

# %% [markdown]
# ### Make functions to subset Monroe county coastal region, Miami-Dade county coastal region, and US virgin islands

# %%
def subset_monroe(ds):
    # Subset TEMP for this location and make an area-weighted mean
    masked = ds.TEMP.where(lats<latmax_monbox).where(lats>latmin_monbox).where(lons_norm<lonmax_monbox).where(lons_norm>lonmin_monbox)
    da = esmlab.weighted_mean(masked, weights=area, dim=['nlat', 'nlon']).compute()

    return da

# %%
def subset_miami(ds):
    # Subset TEMP for this location and make an area-weighted mean
    masked = ds.TEMP.where(lats<latmax_dadebox).where(lats>latmin_dadebox).where(lons_norm<lonmax_dadebox).where(lons_norm>lonmin_dadebox)
    da = esmlab.weighted_mean(masked, weights=area, dim=['nlat', 'nlon']).compute()

    return da

# %%
def subset_vi(ds):
    # Subset TEMP for this location and make an area-weighted mean
    masked = ds.TEMP.where(lats<latmax_VIbox).where(lats>latmin_VIbox).where(lons_norm<lonmax_VIbox).where(lons_norm>lonmin_VIbox)
    da = esmlab.weighted_mean(masked, weights=area, dim=['nlat', 'nlon']).compute()

    return da

# %% [markdown]
# ### Make the regional averages for each box (this step takes awhile: ~30 min total)

# %%
# %%time

da_monroe = subset_monroe(ds)
# Out:
# CPU times: user 38 s, sys: 1.85 s, total: 39.9 s
# Wall time: 10min 19s

# %%
# %%time

da_miami = subset_miami(ds)
# Out:
# CPU times: user 38.8 s, sys: 1.5 s, total: 40.3 s
# Wall time: 10min 8s

# %%
# %%time

da_vi = subset_vi(ds)
# Out:
# CPU times: user 37.4 s, sys: 1.76 s, total: 39.1 s
# Wall time: 10min 9s

# %% [markdown]
# ### Make a few plots of the data

# %%
# %%time

fig = plt.figure(figsize=(10,6))

ax = fig.add_subplot(1,1,1)
ax.set_title('Historical surface ocean temperature in Monroe County coastal region')

da_ensmean = da_monroe.mean(dim='member_id')

for mem in np.arange(0,50,1):
    #print(mem)
    ax.plot(da_monroe.time, da_monroe.isel(member_id=mem),linewidth=1)
ax.plot(da_monroe.time, da_ensmean,linewidth=2, color='black')
ax.set(ylabel='Sea temperature (top 10m)',xlabel='Year');
# Out:
# CPU times: user 206 ms, sys: 979 µs, total: 207 ms
# Wall time: 220 ms
# [Text(0, 0.5, 'Sea temperature (top 10m)'), Text(0.5, 0, 'Year')]

# %%
# %%time

fig = plt.figure(figsize=(10,6))

ax = fig.add_subplot(1,1,1)
ax.set_title('Historical surface ocean temperature in Miami-Dade County coastal region')

da_ensmean = da_miami.mean(dim='member_id')

for mem in np.arange(0,50,1):
    #print(mem)
    ax.plot(da_miami.time, da_miami.isel(member_id=mem),linewidth=1)
ax.plot(da_miami.time, da_ensmean,linewidth=2, color='black')
ax.set(ylabel='Sea temperature (top 10m)',xlabel='Year');
# Out:
# CPU times: user 204 ms, sys: 0 ns, total: 204 ms
# Wall time: 212 ms
# [Text(0, 0.5, 'Sea temperature (top 10m)'), Text(0.5, 0, 'Year')]

# %%
# %%time

fig = plt.figure(figsize=(10,6))

ax = fig.add_subplot(1,1,1)
ax.set_title('Historical surface ocean temperature in US Virgin Islands region')

da_ensmean = da_vi.mean(dim='member_id')

for mem in np.arange(0,50,1):
    #print(mem)
    ax.plot(da_vi.time, da_vi.isel(member_id=mem),linewidth=1)
ax.plot(da_vi.time, da_ensmean,linewidth=2, color='black')
ax.set(ylabel='Sea temperature (top 10m)',xlabel='Year');
# Out:
# CPU times: user 191 ms, sys: 1.18 ms, total: 192 ms
# Wall time: 202 ms
# [Text(0, 0.5, 'Sea temperature (top 10m)'), Text(0.5, 0, 'Year')]

# %% [markdown]
# ### Prepare netcdf to write out

# %%
ds_out = xr.Dataset()
ds_out['Monroe_county_coast_SST'] = da_monroe
ds_out['MiamiDade_county_coast_SST'] = da_miami
ds_out['VirginIslands_region_SST'] = da_vi

ds_out = ds_out.drop(['z_t'])

# %%
file_out = '/glade/work/kristenk/Dunning_innovator_files/regional_SST_avgs_historical.nc'
ds_out.to_netcdf(file_out)
